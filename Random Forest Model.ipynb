# %%
import pandas as pd
df = pd.read_csv('Telco_customer_churn.csv')

# %%
df['Churn Reason'].unique()
# Out:
# array(['Competitor made better offer', 'Moved',
#        'Competitor had better devices',
#        'Competitor offered higher download speeds',
#        'Competitor offered more data', 'Price too high',
#        'Product dissatisfaction', 'Service dissatisfaction',
#        'Lack of self-service on Website', 'Network reliability',
#        'Limited range of services',
#        'Lack of affordable download/upload speed',
#        'Long distance charges', 'Extra data charges', "Don't know",
#        'Poor expertise of online support',
#        'Poor expertise of phone support', 'Attitude of service provider',
#        'Attitude of support person', 'Deceased', nan], dtype=object)

# %%
df['CustomerID'].nunique()
# Out:
# 7043

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
for i in df.columns:
  print(i)
  print(df[i].unique())
  print('===========================')
# Out:
# CustomerID
# ['3668-QPYBK' '9237-HQITU' '9305-CDSKC' ... '2234-XADUH' '4801-JZAZL'
#  '3186-AJIEK']
# ...
# Count
# [1]
# ...
# Country
# ['United States']
# ...
# State
# ['California']
# ...
# City
# ['Los Angeles' 'Beverly Hills' 'Huntington Park' ... 'Standish' 'Tulelake'
#  'Olympic Valley']
# ...
# Zip Code
# [90003 90005 90006 ... 96128 96134 96146]
# ...
# Lat Long
# ['33.964131, -118.272783' '34.059281, -118.30742' '34.048013, -118.293953'
#  ... '40.346634, -120.386422' '41.813521, -121.492666'
#  '39.191797, -120.212401']
# ...
# Latitude
# [33.964131 34.059281 34.048013 ... 40.346634 41.813521 39.191797]
# ...
# Longitude
# [-118.272783 -118.30742  -118.293953 ... -120.386422 -121.492666
#  -120.212401]
# ...
# Gender
# ['Male' 'Female']
# ...
# Senior Citizen
# ['No' 'Yes']
# ...
# Partner
# ['No' 'Yes']
# ...
# Dependents
# ['No' 'Yes']
# ...
# Tenure Months
# [ 2  8 28 49 10  1 47 17  5 34 11 15 18  9  7 12 25 68 55 37  3 27 20  4
#  58 53 13  6 19 59 16 52 24 32 38 54 43 63 21 69 22 61 60 48 40 23 39 35
# ...

# %%
import seaborn as sns
import matplotlib as plt
# for i in df.columns:
ax = sns.countplot(x='Churn Value', hue ='Gender',  data=df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
listcol = ['Gender', 'Senior Citizen',
       'Partner', 'Dependents', 'Phone Service',
       'Multiple Lines', 'Internet Service', 'Online Security',
       'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
       'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method']
for i in listcol:
    plt.figure(i)
    sns.countplot(x='Churn Value', hue =i,  data=df)

# %%
df[listcol]
# col gender > allmale  sum(maleyes) >sum(maleyes)/allmale
df1 = df[['Gender','Churn Value']]
Type = df1['Gender'].unique()
filter = df1[df1['Gender'] == 'Male']
allmale = len(filter)
print(allmale)
filter['Churn Value'].value_counts(normalize =True)*100
# Out:
# 3555
# 0    73.839662
# 1    26.160338
# Name: Churn Value, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
listcol = ['Gender', 'Senior Citizen',
       'Partner', 'Dependents', 'Phone Service',
       'Multiple Lines', 'Internet Service', 'Online Security',
       'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
       'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method']
for i in listcol:
    plt.figure(i)
    sns.histplot(df,x=i, hue ='Churn Value', stat="probability", multiple="fill", shrink=.8)

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'Two year', 'One year'], dtype=object)

# %%
#import Data
import pandas as pd
df = pd.read_csv('Telco_customer_churn.csv')

listcol = ['Gender', 'Senior Citizen','Partner', 'Dependents', 'Tenure Months', 'Phone Service',
       'Multiple Lines', 'Internet Service', 'Online Security','Online Backup', 'Device Protection',
       'Tech Support', 'Streaming TV','Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
       'Monthly Charges', 'Total Charges','Churn Value']
df = df[listcol]
import matplotlib.pyplot as plt
import seaborn as sns
tmp = df.copy()
plt.figure(figsize=(15,8))
heatmap = sns.heatmap(data=tmp.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.show()

# %%
# sns.histplot(x='Churn Value',data =df,bins=2)
df['Churn Value'].value_counts().plot(kind='barh', figsize=(8, 6))

# %% [markdown]
# Change type Data

# %%
#import Data
import pandas as pd
df = pd.read_csv('Telco_customer_churn.csv')

listcol = ['Gender', 'Senior Citizen','Partner', 'Dependents', 'Tenure Months', 'Phone Service',
       'Multiple Lines', 'Internet Service', 'Online Security','Online Backup', 'Device Protection',
       'Tech Support', 'Streaming TV','Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
       'Monthly Charges', 'Total Charges','Churn Value']
df = df[listcol]
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   object
#  1   Senior Citizen     7043 non-null   object
#  2   Partner            7043 non-null   object
#  3   Dependents         7043 non-null   object
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   object
#  6   Multiple Lines     7043 non-null   object
#  7   Internet Service   7043 non-null   object
#  8   Online Security    7043 non-null   object
#  9   Online Backup      7043 non-null   object
#  10  Device Protection  7043 non-null   object
#  11  Tech Support       7043 non-null   object
#  12  Streaming TV       7043 non-null   object
#  13  Streaming Movies   7043 non-null   object
#  14  Contract           7043 non-null   object
#  15  Paperless Billing  7043 non-null   object
# ...

# %%
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')
df.isnull().sum()
df[df['Total Charges'].isnull() == True]
#Removing missing values 
df.dropna(how = 'any', inplace = True)
#telco_data.fillna(0)
# Get the max tenure
# print(df['Tenure Months'].max())
# # Group the tenure in bins of 12 months
# labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]

# df['tenure_group'] = pd.cut(df['Tenure Months'], range(1, 80, 12), right=False, labels=labels)
# print(df['tenure_group'].value_counts())

# %%
#Select Columns
listcol = ['Gender', 'Senior Citizen','Partner', 'Dependents', 'Tenure Months', 'Phone Service',
       'Multiple Lines', 'Internet Service', 'Online Security','Online Backup', 'Device Protection',
       'Tech Support', 'Streaming TV','Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
       'Monthly Charges', 'Total Charges','Churn Value']

# %%
#plot Churn vs "contract","Tenure Month"
#plot correlation
#corr Churn vs 'Gender', 'Senior Citizen','Partner', 'Dependents'


#corr 'Tenure Months'

#corr 'Phone Service','Multiple Lines', 'Internet Service', 'Online Security','Online Backup', 'Device Protection','Tech Support', 'Streaming TV','Streaming Movies'
#corr 'Contract'
#corr 'Paperless Billing', 'Payment Method'
#corr 'Monthly Charges', 'Total Charges'
df[listcol]
# Out:
#       Gender Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 0       Male             No      No         No              2           Yes
# 1     Female             No      No        Yes              2           Yes
# 2     Female             No      No        Yes              8           Yes
# 3     Female             No     Yes        Yes             28           Yes
# 4       Male             No      No        Yes             49           Yes
# ...      ...            ...     ...        ...            ...           ...
# 7038  Female             No      No         No             72           Yes
# 7039    Male             No     Yes        Yes             24           Yes
# 7040  Female             No     Yes        Yes             72           Yes
# 7041  Female             No     Yes        Yes             11            No
# 7042    Male             No      No         No             66           Yes
#
# ...

# %%
import matplotlib as plt
listcol = ['Gender', 'Senior Citizen','Partner', 'Dependents','Churn Value']
corr_df = pd.get_dummies(df[listcol])
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(corr_df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-98bf7acfab3f> in <module>()
#       2 listcol = ['Gender', 'Senior Citizen','Partner', 'Dependents','Churn Value']
#       3 corr_df = pd.get_dummies(df[listcol])
# ----> 4 plt.figure(figsize=(16, 6))
#       5 heatmap = sns.heatmap(corr_df.corr(), vmin=-1, vmax=1, annot=True)
#       6 heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
#
# TypeError: 'module' object is not callable

# %%
corr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Churn Value         7032 non-null   int64
#  1   Gender_Female       7032 non-null   uint8
#  2   Gender_Male         7032 non-null   uint8
#  3   Senior Citizen_No   7032 non-null   uint8
#  4   Senior Citizen_Yes  7032 non-null   uint8
#  5   Partner_No          7032 non-null   uint8
#  6   Partner_Yes         7032 non-null   uint8
#  7   Dependents_No       7032 non-null   uint8
#  8   Dependents_Yes      7032 non-null   uint8
# dtypes: int64(1), uint8(8)
# memory usage: 164.8 KB

# %%
corr_df['Churn Value'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# # Prepare Data

# %%
#import Data
import pandas as pd
df = pd.read_csv('Telco_customer_churn.csv')

listcol = ['Gender', 'Senior Citizen','Partner', 'Dependents', 'Tenure Months', 'Phone Service',
       'Multiple Lines', 'Internet Service', 'Online Security','Online Backup', 'Device Protection',
       'Tech Support', 'Streaming TV','Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
       'Monthly Charges', 'Total Charges','Churn Value']
df = df[listcol]
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   object
#  1   Senior Citizen     7043 non-null   object
#  2   Partner            7043 non-null   object
#  3   Dependents         7043 non-null   object
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   object
#  6   Multiple Lines     7043 non-null   object
#  7   Internet Service   7043 non-null   object
#  8   Online Security    7043 non-null   object
#  9   Online Backup      7043 non-null   object
#  10  Device Protection  7043 non-null   object
#  11  Tech Support       7043 non-null   object
#  12  Streaming TV       7043 non-null   object
#  13  Streaming Movies   7043 non-null   object
#  14  Contract           7043 non-null   object
#  15  Paperless Billing  7043 non-null   object
# ...

# %%
df.info()
df
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Change Type
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')
print(df.isnull().sum())
print(df[df['Total Charges'].isnull() == True])
#Removing missing values 
df.dropna(how = 'any', inplace = True)
#telco_data.fillna(0)

# Get the max tenure
print(df['Tenure Months'].max())
# Group the tenure in bins of 12 months
labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]

df['tenure_group'] = pd.cut(df['Tenure Months'], range(1, 80, 12), right=False, labels=labels)
print(df['tenure_group'].value_counts())
# Out:
# Gender                0
# Senior Citizen        0
# Partner               0
# Dependents            0
# Tenure Months         0
# Phone Service         0
# Multiple Lines        0
# Internet Service      0
# Online Security       0
# Online Backup         0
# Device Protection     0
# Tech Support          0
# Streaming TV          0
# Streaming Movies      0
# Contract              0
# Paperless Billing     0
# Payment Method        0
# Monthly Charges       0
# Total Charges        11
# Churn Value           0
# dtype: int64
#       Gender Senior Citizen Partner Dependents  Tenure Months Phone Service  \
# 2234  Female             No     Yes         No              0            No
# 2438    Male             No      No         No              0           Yes
# 2568  Female             No     Yes         No              0           Yes
# 2667    Male             No     Yes        Yes              0           Yes
# ...

# %%
#check type
df.dtypes
# Out:
# Gender                 object
# Senior Citizen         object
# Partner                object
# Dependents             object
# Tenure Months           int64
# Phone Service          object
# Multiple Lines         object
# Internet Service       object
# Online Security        object
# Online Backup          object
# Device Protection      object
# Tech Support           object
# Streaming TV           object
# Streaming Movies       object
# Contract               object
# Paperless Billing      object
# Payment Method         object
# Monthly Charges       float64
# Total Charges         float64
# Churn Value             int64
# tenure_group         category
# dtype: object

# %%
#convert categorical to dummy variable
df_dummies = pd.get_dummies(df)
df_dummies.head()
df_dummies.info()
# plt.figure(figsize=(20,8))
df_dummies.corr()['Churn Value'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 53 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Tenure Months                             7032 non-null   int64
#  1   Monthly Charges                           7032 non-null   float64
#  2   Total Charges                             7032 non-null   float64
#  3   Churn Value                               7032 non-null   int64
#  4   Gender_Female                             7032 non-null   uint8
#  5   Gender_Male                               7032 non-null   uint8
#  6   Senior Citizen_No                         7032 non-null   uint8
#  7   Senior Citizen_Yes                        7032 non-null   uint8
#  8   Partner_No                                7032 non-null   uint8
#  9   Partner_Yes                               7032 non-null   uint8
# ...

# %%
#import Data
import pandas as pd
df = pd.read_csv('Telco_customer_churn.csv')

listcol = ['Gender', 'Senior Citizen','Partner', 'Dependents', 'Tenure Months', 'Phone Service',
       'Multiple Lines', 'Internet Service', 'Online Security','Online Backup', 'Device Protection',
       'Tech Support', 'Streaming TV','Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
       'Monthly Charges', 'Total Charges','Churn Value']
df = df[listcol]
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   object
#  1   Senior Citizen     7043 non-null   object
#  2   Partner            7043 non-null   object
#  3   Dependents         7043 non-null   object
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   object
#  6   Multiple Lines     7043 non-null   object
#  7   Internet Service   7043 non-null   object
#  8   Online Security    7043 non-null   object
#  9   Online Backup      7043 non-null   object
#  10  Device Protection  7043 non-null   object
#  11  Tech Support       7043 non-null   object
#  12  Streaming TV       7043 non-null   object
#  13  Streaming Movies   7043 non-null   object
#  14  Contract           7043 non-null   object
#  15  Paperless Billing  7043 non-null   object
# ...

# %%
#select columns
dftest =df[["Senior Citizen","Dependents","Internet Service", "Total Charges","Tenure Months",'Churn Value']]
#change Total charges to integer and drop nan
dftest['Total Charges'] = pd.to_numeric(dftest['Total Charges'], errors = "coerce") # convert " " to nan
dftest['Total Charges'].isnull().sum()
dftest[dftest['Total Charges'].isnull() == True]
#drop na
dftest.dropna(how='any', inplace =True)
dftest.info()
#change str to integer for model
dftest['Senior Citizen'] = dftest['Senior Citizen'].map({'No':0,'Yes':1})
dftest['Dependents'] = dftest['Dependents'].map({'No':0,'Yes':1})
dftest['Internet Service'] = dftest['Internet Service'].map({'No':0,'DSL':1, 'Fiber optic':2})
dftest.info()
#buid x,y to feed model
x = dftest.drop('Churn Value',axis=1)
y = dftest['Churn Value']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Senior Citizen    7032 non-null   object
#  1   Dependents        7032 non-null   object
#  2   Internet Service  7032 non-null   object
#  3   Total Charges     7032 non-null   float64
#  4   Tenure Months     7032 non-null   int64
#  5   Churn Value       7032 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 384.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Senior Citizen    7032 non-null   int64
#  1   Dependents        7032 non-null   int64
#  2   Internet Service  7032 non-null   int64
#  3   Total Charges     7032 non-null   float64
# ...

# %%
#train test split
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
#modeling
from pandas.core.common import random_state
#reference https://github.com/pik1989/MLProject-ChurnPrediction
#decision tree
model_dt = DecisionTreeClassifier(criterion = "gini", random_state=100,max_depth=6, min_samples_leaf=8)
model_dt.fit(x_train,y_train)
#Predict the response for test dataset
y_pred = model_dt.predict(x_test)
y_score = model_dt.score(x_test,y_pred)

# %%
#report performance
from sklearn.metrics import classification_report
model_score = model_dt.score(x_test, y_test)
print(model_score)
print(classification_report(y_test, y_pred,labels=[0, 1]))
# Out:
# 0.8038379530916845
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      1057
#            1       0.65      0.47      0.54       350
#
#     accuracy                           0.80      1407
#    macro avg       0.74      0.69      0.71      1407
# weighted avg       0.79      0.80      0.79      1407

# %%
#visualize tree map
from IPython.display import SVG
from graphviz import Source
from IPython.display import display
from sklearn.tree import DecisionTreeClassifier, export_graphviz
graph = Source(export_graphviz(model_dt, out_file=None,  
                filled=True, rounded=True,
                special_characters=True,feature_names = x_train.columns ,class_names=['0','1']))

display(SVG(graph.pipe(format='svg')))

# %%
x['Tenure Months'].value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 38     59
# 28     57
# 39     56
# 44     51
# 36     50
# Name: Tenure Months, Length: 72, dtype: int64

# %%
#resampling
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=100)
x_resampled, y_resampled = sm.fit_resample(x,y)
# sm.fit_sample(x,y)
x_train_re, x_test_re, y_train_re, y_test_re = train_test_split(x_resampled, y_resampled, test_size=0.2)

# %%
#Compare y, y_resampled
print(y.value_counts(),len(y))
print(y_resampled.value_counts(), len(y_resampled))
# Out:
# 0    5163
# 1    1869
# Name: Churn Value, dtype: int64 7032
# 1    5163
# 0    5163
# Name: Churn Value, dtype: int64 10326

# %%
#Decision tree Modeling resampled
model_dt_resam = DecisionTreeClassifier(criterion='gini', random_state=100, max_depth=6, min_samples_leaf=8)
model_dt_resam.fit(x_train_re, y_train_re)
#Prediction
y_pred_re = model_dt_resam.predict(x_test_re)
#report accuracy
from sklearn.metrics import classification_report
model_score_r = model_dt_resam.score(x_test_re, y_test_re)
print(model_score_r)
print(classification_report(y_test_re, y_pred_re))
conf = metrics.confusion_matrix(y_test_re, y_pred_re)
print(metrics.confusion_matrix(y_test_re, y_pred_re))
# Out:
# 0.7739593417231365
#               precision    recall  f1-score   support
#
#            0       0.82      0.70      0.75      1028
#            1       0.74      0.85      0.79      1038
#
#     accuracy                           0.77      2066
#    macro avg       0.78      0.77      0.77      2066
# weighted avg       0.78      0.77      0.77      2066
#
# [[719 309]
#  [158 880]]

# %%
conf = metrics.confusion_matrix(y_test_re, y_pred_re)
print("               Confusion matrix")
print("                 notChurn      Churn")
print("Actual notChurn %6d"% conf[0,0]+"        %5d"% conf[0,1])
print("Actual Churn    %6d   "% conf[1,0]+"     %5d"% conf[1,1])
# Out:
#                Confusion matrix
#                  notChurn      Churn
# Actual notChurn    674          335
# Actual Churn       148          909

# %%
#prepare onehot encoding

#traintest split
    #validation set
        #cross fold
#modeling with train_valid
    #tuning parameter with test_valid
        #select paramerter from cross fold
#evaluation performance with test set
#conclution
#import Data
import pandas as pd
df = pd.read_csv('Telco_customer_churn.csv')

listcol = ['Gender', 'Senior Citizen','Partner', 'Dependents', 'Tenure Months', 'Phone Service',
       'Multiple Lines', 'Internet Service', 'Online Security','Online Backup', 'Device Protection',
       'Tech Support', 'Streaming TV','Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
       'Monthly Charges', 'Total Charges','Churn Value']
df = df[listcol]
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   object
#  1   Senior Citizen     7043 non-null   object
#  2   Partner            7043 non-null   object
#  3   Dependents         7043 non-null   object
#  4   Tenure Months      7043 non-null   int64
#  5   Phone Service      7043 non-null   object
#  6   Multiple Lines     7043 non-null   object
#  7   Internet Service   7043 non-null   object
#  8   Online Security    7043 non-null   object
#  9   Online Backup      7043 non-null   object
#  10  Device Protection  7043 non-null   object
#  11  Tech Support       7043 non-null   object
#  12  Streaming TV       7043 non-null   object
#  13  Streaming Movies   7043 non-null   object
#  14  Contract           7043 non-null   object
#  15  Paperless Billing  7043 non-null   object
# ...

# %% [markdown]
# #Prepare onehot encoding

# %%
#select columns
dftest = df
#change Total charges to integer and drop nan
dftest['Total Charges'] = pd.to_numeric(dftest['Total Charges'], errors = "coerce") # convert " " to nan
dftest['Total Charges'].isnull().sum()
dftest[dftest['Total Charges'].isnull() == True]
#drop na
dftest.dropna(how='any', inplace =True)

#group tenure in bin 12 month
labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]
dftest['Tenure Months'] = pd.cut(dftest['Tenure Months'], range(1, 80, 12), right=False, labels=labels)
dftest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7032 non-null   object
#  1   Senior Citizen     7032 non-null   object
#  2   Partner            7032 non-null   object
#  3   Dependents         7032 non-null   object
#  4   Tenure Months      7032 non-null   category
#  5   Phone Service      7032 non-null   object
#  6   Multiple Lines     7032 non-null   object
#  7   Internet Service   7032 non-null   object
#  8   Online Security    7032 non-null   object
#  9   Online Backup      7032 non-null   object
#  10  Device Protection  7032 non-null   object
#  11  Tech Support       7032 non-null   object
#  12  Streaming TV       7032 non-null   object
#  13  Streaming Movies   7032 non-null   object
#  14  Contract           7032 non-null   object
#  15  Paperless Billing  7032 non-null   object
# ...

# %%
print('Number of Churn ',len(dftest[dftest['Churn Value']==1]))
print('Number Not Churn',len(dftest[dftest['Churn Value']==0]))
# Out:
# Number of Churn  1869
# Number Not Churn 5163

# %%
#get dummies
dftest = pd.get_dummies(dftest)

#buid x,y for model
x = dftest.drop('Churn Value',axis=1)
y = dftest['Churn Value']
print(dftest.info(), dftest.head())
#mean normalized
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scale = scaler.fit_transform(x[['Monthly Charges','Total Charges']])
x['Monthly Charges'] = scale[:,0]
x['Total Charges'] = scale[:,1]
x = x.to_numpy()
y = y.to_numpy()

# %% [markdown]
# # Resampling

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
x
# Out:
# array([[-0.36392329, -0.95964911,  0.        , ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.19617818, -0.94045745,  1.        , ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.15848901, -0.64536922,  1.        , ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 1.27649259,  2.24105565,  1.        , ...,  1.        ,
#          0.        ,  0.        ],
#        [-1.17000405, -0.85451414,  1.        , ...,  0.        ,
#          1.        ,  0.        ],
#        [ 1.35793167,  2.01234407,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
#resampling
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=100)
x_resampled, y_resampled = sm.fit_resample(x,y)

# %%
#split data
from sklearn.model_selection import train_test_split
x_train_re, x_test_re, y_train_re, y_test_re = train_test_split(x_resampled, y_resampled, test_size=round(len(x)*0.3) , shuffle =True, random_state=100)
# print('x_train_re',len(x_train_re))
print('x_train_re',len(x_train_re))
# Out:
# x_train_re 8216

# %%
#split data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=round(len(x)*0.3) , shuffle =True, random_state=100)
# print('x_train_re',len(x_train_re))
print('x_train',len(x_train))
# Out:
# x_train 4922

# %%
#resampling
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=100)
x_resampled, y_resampled = sm.fit_resample(x_train,y_train)

# %%
# Random forest kfold + grid search + resampling + scaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
clf = RandomForestClassifier(random_state = 100)
clf.fit(x_resampled, y_resampled)


#performance on train_set
y_pred = clf.predict(x_train)
model_score_r = clf.score(x_train, y_train)
print(classification_report(y_train,y_pred))
print(f'AUC Score :{roc_auc_score(y_train, clf.predict_proba(x_train)[:,1])}')
#performance on test_set

y_pred = clf.predict(x_test)
model_score_r = clf.score(x_test, y_test)
print(classification_report(y_test,y_pred))
print(f'AUC Score :{roc_auc_score(y_test, clf.predict_proba(x_test)[:,1])}')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3619
#            1       0.99      1.00      1.00      1303
#
#     accuracy                           1.00      4922
#    macro avg       1.00      1.00      1.00      4922
# weighted avg       1.00      1.00      1.00      4922
#
# AUC Score :0.9999877002865196
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85      1544
#            1       0.59      0.55      0.57       566
#
#     accuracy                           0.77      2110
#    macro avg       0.71      0.70      0.71      2110
# weighted avg       0.77      0.77      0.77      2110
#
# AUC Score :0.8209111069408082

# %%
from sklearn.ensemble import RandomForestRegressor
from pprint import pprint
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(clf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 100,
#  'verbose': 0,
#  'warm_start': False}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
y_pred_proba = clf.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
a = clf.feature_importances_
np.sort(a)
# Out:
# array([0.00185832, 0.00233564, 0.00258915, 0.00264403, 0.00269319,
#        0.00279229, 0.00294413, 0.00295748, 0.0034608 , 0.0036688 ,
#        0.00695834, 0.00802013, 0.00903351, 0.00915345, 0.01004947,
#        0.01008595, 0.01035763, 0.01048347, 0.01068101, 0.01094071,
#        0.0111745 , 0.01122097, 0.01146983, 0.0118827 , 0.01207073,
#        0.01210727, 0.01270161, 0.01274791, 0.01287083, 0.01340736,
#        0.01351684, 0.01401204, 0.01481164, 0.01519931, 0.01529633,
#        0.01589199, 0.01590583, 0.01596444, 0.01651899, 0.01665578,
#        0.01829617, 0.02095194, 0.03449998, 0.03531875, 0.04420925,
#        0.0454973 , 0.04560646, 0.05866777, 0.08022152, 0.10034838,
#        0.11724808])

# %%
b = dftest.drop('Churn Value',axis=1)
b = b.columns
# 0 1
print(b[0])
print(b[1])
print(b[42])
# Out:
# Monthly Charges
# Total Charges
# Contract_Month-to-month

# %% [markdown]
# # Train test set , validation set -> k-fold cross validation

# %%
parameters ={
      'max_depth': [5,10,15,20],
      'criterion' : ['gini', 'entropy'],
      'max_features': ['auto', 'sqrt'],
      'min_samples_leaf': [3,7,10],
      'min_samples_split': [2,7,10],
      'n_estimators': [200,500]}

# %%
# %%time
# Random forest kfold + grid search + resampling + scaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
rf = RandomForestClassifier()
parameters ={
      'max_depth': [5,10,15,20],
      'criterion' : ['gini', 'entropy'],
      'max_features': ['auto', 'sqrt'],
      'min_samples_leaf': [3,7,10],
      'min_samples_split': [2,7,10],
      'n_estimators': [200,500]}
clf = GridSearchCV(rf, parameters, cv=5)
clf.fit(x_train_re, y_train_re)

y_pred = clf.predict(x_test_re)
model_score_r = clf.score(x_test_re, y_test_re)
print(classification_report(y_test_re,y_pred))
print(f'AUC Score :{roc_auc_score(y_test_re, clf.predict_proba(x_test_re)[:,1])}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85      1074
#            1       0.84      0.87      0.85      1036
#
#     accuracy                           0.85      2110
#    macro avg       0.85      0.85      0.85      2110
# weighted avg       0.85      0.85      0.85      2110
#
# AUC Score :0.923650805634046

# %%
print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 500}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
y_pred_proba = clf.predict_proba(x_test_re)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test_re,  y_pred_proba)
auc = metrics.roc_auc_score(y_test_re, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
model_score_r = clf.score(x_test, y_test)
print(classification_report(y_test,y_pred))
print(f'AUC Score :{roc_auc_score(y_test, clf.predict_proba(x_test)[:,1])}')

# %%
parameters ={'criterion': 'entropy', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 200}

# %%
#best parameter

# %%
# %%time
# Random forest kfold + grid search + resampling 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
rf = RandomForestClassifier()
parameters ={
    'max_depth': [5,10,15,20,None],
    'bootstrap': [True,False],
      'criterion' : ['gini', 'entropy'],
      'max_features': ['auto', 'sqrt'],
      'min_samples_leaf': [1,3,5,10],
      'min_samples_split': [2,5,10],
      'n_estimators': [20,50,100,200]
      }
clf = GridSearchCV(rf, parameters, cv=5)
clf.fit(x_resampled, y_resampled)
print(f"best parameters is {clf.best_params_}")
#performance on train_set
y_pred = clf.predict(x_train)
model_score_r = clf.score(x_train, y_train)
print(classification_report(y_train,y_pred))
print(f'AUC Score :{roc_auc_score(y_train, clf.predict_proba(x_train)[:,1])}')
#performance on test_set
y_pred = clf.predict(x_test)
model_score_r = clf.score(x_test, y_test)
print(classification_report(y_test,y_pred))
print(f'AUC Score :{roc_auc_score(y_test, clf.predict_proba(x_test)[:,1])}')
# Out:
# best parameters is {'bootstrap': False, 'criterion': 'gini', 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      4127
#            1       0.91      0.99      0.95      1499
#
#     accuracy                           0.97      5626
#    macro avg       0.95      0.98      0.96      5626
# weighted avg       0.97      0.97      0.97      5626
#
# AUC Score :0.9953416161618447
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      1036
#            1       0.91      0.99      0.95       370
#
#     accuracy                           0.97      1406
#    macro avg       0.95      0.98      0.97      1406
# weighted avg       0.97      0.97      0.97      1406
#
# AUC Score :0.995465929249713

# %%
# %%time
# Random forest kfold + grid search + resampling 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
rf = RandomForestClassifier(random_state=100)
parameters ={
    'max_depth': [5,10,15,20,None],    
    'criterion' : ['gini', 'entropy'],
    'max_features': ['auto', 'sqrt'],
    'min_samples_leaf': [1,3,5,10],
    'min_samples_split': [2,5,10],
    'n_estimators': [20,50,100,200]
    }
clf = GridSearchCV(rf, parameters, cv=5)
clf.fit(x_resampled, y_resampled)
print(f"best parameters is {clf.best_params_}")
#performance on train_set
y_pred = clf.predict(x_train)
model_score_r = clf.score(x_train, y_train)
print(classification_report(y_train,y_pred))
print(f'AUC Score :{roc_auc_score(y_train, clf.predict_proba(x_train)[:,1])}')
#performance on test_set
y_pred = clf.predict(x_test)
model_score_r = clf.score(x_test, y_test)
print(classification_report(y_test,y_pred))
print(f'AUC Score :{roc_auc_score(y_test, clf.predict_proba(x_test)[:,1])}')
# Out:
# best parameters is {'criterion': 'gini', 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99      4127
#            1       0.93      1.00      0.96      1499
#
#     accuracy                           0.98      5626
#    macro avg       0.97      0.99      0.97      5626
# weighted avg       0.98      0.98      0.98      5626
#
# AUC Score :0.9985016260739532
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1036
#            1       0.58      0.58      0.58       370
#
#     accuracy                           0.78      1406
#    macro avg       0.71      0.72      0.71      1406
# weighted avg       0.78      0.78      0.78      1406
#
# AUC Score :0.8205128874047792

# %%
#best parameters is {'criterion': 'gini', 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
# %%time
# Random forest kfold + grid search + resampling 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
clf = RandomForestClassifier(criterion='gini',max_depth = 20, max_features='auto', min_samples_leaf=1,
                             min_samples_split=2, n_estimators=200,random_state=100)
clf.fit(x_resampled, y_resampled)

# print(f"best parameters is {clf.best_params_}")
#performance on train_set
y_pred = clf.predict(x_train)
model_score_r = clf.score(x_train, y_train)
print(classification_report(y_train,y_pred))
print(f'AUC Score :{roc_auc_score(y_train, clf.predict_proba(x_train)[:,1])}')
#performance on test_set
y_pred = clf.predict(x_test)
model_score_r = clf.score(x_test, y_test)
print(classification_report(y_test,y_pred))
print(f'AUC Score :{roc_auc_score(y_test, clf.predict_proba(x_test)[:,1])}')
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      3619
#            1       0.95      1.00      0.97      1303
#
#     accuracy                           0.98      4922
#    macro avg       0.97      0.99      0.98      4922
# weighted avg       0.99      0.98      0.98      4922
#
# AUC Score :0.9993127004932822
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85      1544
#            1       0.58      0.57      0.58       566
#
#     accuracy                           0.78      2110
#    macro avg       0.71      0.71      0.71      2110
# weighted avg       0.77      0.78      0.77      2110
#
# AUC Score :0.8274095323971512

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
y_pred_proba = clf.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
#fit all data with best parameter
#best parameters is {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 100}

# %%
# %%time
# Random forest model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
clf = RandomForestClassifier(criterion='entropy',max_depth = 20, max_features='auto', min_samples_leaf=3,
                             min_samples_split=5, n_estimators=100,random_state=100)
clf.fit(x_resampled, y_resampled)

y_pred = clf.predict(x_test)
model_score_r = clf.score(x_test, y_test)
print(classification_report(y_test,y_pred))
print(f'AUC Score :{roc_auc_score(y_test, clf.predict_proba(x_test)[:,1])}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      1544
#            1       0.58      0.63      0.60       566
#
#     accuracy                           0.78      2110
#    macro avg       0.72      0.73      0.72      2110
# weighted avg       0.78      0.78      0.78      2110
#
# AUC Score :0.8407067595525367

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
y_pred_proba = clf.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
# %%time
# Random forest Best model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
clf = RandomForestClassifier(criterion='entropy',max_depth = 20, max_features='auto', min_samples_leaf=3,
                             min_samples_split=5, n_estimators=100,random_state=100)
clf.fit(x_train, y_train)

y_pred = clf.predict(x_train)
model_score_r = clf.score(x_train, y_train)
print(classification_report(y_train,y_pred))
print(f'AUC Score :{roc_auc_score(y_train, clf.predict_proba(x_train)[:,1])}')

y_pred = clf.predict(x_test)
model_score_r = clf.score(x_test, y_test)
print(classification_report(y_test,y_pred))
print(f'AUC Score :{roc_auc_score(y_test, clf.predict_proba(x_test)[:,1])}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93      4127
#            1       0.86      0.72      0.79      1499
#
#     accuracy                           0.90      5626
#    macro avg       0.88      0.84      0.86      5626
# weighted avg       0.89      0.90      0.89      5626
#
# AUC Score :0.9637108043760051
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1036
#            1       0.65      0.52      0.58       370
#
#     accuracy                           0.80      1406
#    macro avg       0.74      0.71      0.72      1406
# weighted avg       0.79      0.80      0.79      1406
#
# AUC Score :0.8371569445893772

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
y_pred_proba = clf.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
# Random forest Best model
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(x_resampled, y_resampled)

# %%
# %%time
# Random forest kfold + grid search + not resampling 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
rf = RandomForestClassifier()
parameters ={
    'max_depth': [5,10,15,20],
      'criterion' : ['gini', 'entropy'],
      'max_features': ['auto', 'sqrt'],
      'min_samples_leaf': [3,5,7,10],
      'min_samples_split': [2,5,7,10],
      'n_estimators': [20,50,100,200]
      }
clf = GridSearchCV(rf, parameters, cv=5)
clf.fit(x_train, y_train)
print(f"best parameters is {clf.best_params_}")
#performance on train_set
y_pred = clf.predict(x_train)
model_score_r = clf.score(x_train, y_train)
print(classification_report(y_train,y_pred))
print(f'AUC Score :{roc_auc_score(y_train, clf.predict_proba(x_train)[:,1])}')
#performance on test_set
y_pred = clf.predict(x_test)
model_score_r = clf.score(x_test, y_test)
print(classification_report(y_test,y_pred))
print(f'AUC Score :{roc_auc_score(y_test, clf.predict_proba(x_test)[:,1])}')
# Out:
# best parameters is {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      4127
#            1       0.79      0.65      0.71      1499
#
#     accuracy                           0.86      5626
#    macro avg       0.84      0.79      0.81      5626
# weighted avg       0.86      0.86      0.86      5626
#
# AUC Score :0.9352841317521592
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1036
#            1       0.64      0.50      0.56       370
#
#     accuracy                           0.80      1406
#    macro avg       0.74      0.70      0.71      1406
# weighted avg       0.78      0.80      0.79      1406
#
# AUC Score :0.8407948972138162
# CPU times: user 38min 38s, sys: 8.34 s, total: 38min 46s
# Wall time: 39min 11s

# %%
# 'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 50

# %%
# %%time
# Random forest Best model
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
clf = RandomForestClassifier(criterion='gini',max_depth = 20, max_features='sqrt', min_samples_leaf=5,
                             min_samples_split=5, n_estimators=50,random_state=100)
clf.fit(x_train, y_train)

y_pred = clf.predict(x_train)
model_score_r = clf.score(x_train, y_train)
print(classification_report(y_train,y_pred))
print(f'AUC Score :{roc_auc_score(y_train, clf.predict_proba(x_train)[:,1])}')

y_pred = clf.predict(x_test)
model_score_r = clf.score(x_test, y_test)
print(classification_report(y_test,y_pred))
print(f'AUC Score :{roc_auc_score(y_test, clf.predict_proba(x_test)[:,1])}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      4127
#            1       0.80      0.65      0.72      1499
#
#     accuracy                           0.86      5626
#    macro avg       0.84      0.80      0.82      5626
# weighted avg       0.86      0.86      0.86      5626
#
# AUC Score :0.9357892742645813
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1036
#            1       0.65      0.50      0.57       370
#
#     accuracy                           0.80      1406
#    macro avg       0.74      0.70      0.72      1406
# weighted avg       0.79      0.80      0.79      1406
#
# AUC Score :0.8391800584368151

# %%
clf.feature_importances_
# Out:
# array([0.09163766, 0.12096589, 0.01037621, 0.01146134, 0.00714235,
#        0.00659184, 0.01125661, 0.01028211, 0.03463224, 0.03765199,
#        0.07366802, 0.00687748, 0.00482952, 0.0041867 , 0.00400415,
#        0.01480308, 0.00330979, 0.00186132, 0.00936109, 0.00192605,
#        0.00878908, 0.01488139, 0.03932209, 0.00512882, 0.0414433 ,
#        0.00519154, 0.01085395, 0.01277095, 0.0039283 , 0.00748309,
#        0.01744541, 0.0010603 , 0.00637508, 0.08582848, 0.00658714,
#        0.01587304, 0.00717457, 0.00571877, 0.00859581, 0.00758684,
#        0.00039084, 0.0084156 , 0.08752247, 0.01418847, 0.03350723,
#        0.01120076, 0.0096386 , 0.00617181, 0.00642135, 0.03720997,
#        0.00646951])

# %%
a = clf.feature_importances_
a
# Out:
# array([0.09163766, 0.12096589, 0.01037621, 0.01146134, 0.00714235,
#        0.00659184, 0.01125661, 0.01028211, 0.03463224, 0.03765199,
#        0.07366802, 0.00687748, 0.00482952, 0.0041867 , 0.00400415,
#        0.01480308, 0.00330979, 0.00186132, 0.00936109, 0.00192605,
#        0.00878908, 0.01488139, 0.03932209, 0.00512882, 0.0414433 ,
#        0.00519154, 0.01085395, 0.01277095, 0.0039283 , 0.00748309,
#        0.01744541, 0.0010603 , 0.00637508, 0.08582848, 0.00658714,
#        0.01587304, 0.00717457, 0.00571877, 0.00859581, 0.00758684,
#        0.00039084, 0.0084156 , 0.08752247, 0.01418847, 0.03350723,
#        0.01120076, 0.0096386 , 0.00617181, 0.00642135, 0.03720997,
#        0.00646951])

# %%
1,10,33,38,42

# %%
b = dftest.drop('Churn Value',axis=1)
b = b.columns
print(b[0])
print(b[1])
print(b[10])
print(b[33])
print(b[38])
print(b[42])
# Out:
# Monthly Charges
# Total Charges
# Tenure Months_1 - 12
# Tech Support_No
# Streaming TV_Yes
# Contract_Month-to-month

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
y_pred_proba = clf.predict_proba(x_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
